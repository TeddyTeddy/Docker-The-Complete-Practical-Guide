# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Let us start with simple web-app, which shows background color red when run.
# That works fine as hard coded. But if you decide to change the color in the future, you have to change the app code. The best practice is to move such information out of the app code and into an environment variable (e.g. named app_color ) The next time you can set the env variable value to blue and the app has new color.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Once the app is packaged into a docker image, you will the run the app:
#
# docker run simple-webapp
#
# However, if you now wish to pass the environment variable to the docker image, you need to use -e option
# to set an environment variable within the container:
#
# docker run -e APP_COLOR=blue simple-webapp
#
# To run multiple simple-webapp containers with different colors each:
#
# docker run -e APP_COLOR=red simple-webapp
# docker run -e APP_COLOR=pink simple-webapp
# docker run -e APP_COLOR=black simple-webapp
#
# Q) How do you find the environment variable set on a running container?
# A) Use docker inspect command > config section
