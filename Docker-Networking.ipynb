# %% [raw]
# When you install docker, it creates three networks automatically:
#
#     - Bridge
#     - None
#     - Host
#
# Bridge is the default network, a container gets attached to.
# If you would like to associate the container with any other network,
# specify the network via --network command line parameter as shown below:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Lets look at these networks. The Bridge network is a private internal network created
# by Docker on the Docker host. All containers are attached to Bridge network by default,
# they get an internal IP address usually in the range 172.17 series:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Container can access each other's IP if required. To access any of these containers from outside world,
# map the ports of these containers to the ports of the docker host (e.g. -p 80:8080 )
#
# (???) Another way to access containers externally is to associate the container to the host network.
# This takes out any network isolation between the Docker host and the docker container.
# Meaning, if you were to run a web server container on port 5000, which is automatically accessible
# on the same port externally without requiring any port mapping as the web container uses
# the hosts network. This would also mean that unlike Bridge Network case, you will NOT be able to
# run multiple web container on the same host on the same port.
#
# With the NONE network, the containers are not attached to any network
# and does NOT have any access to external network or the the other containers; They run in an isolated network.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## User Defined Networks

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# In the above BRIDGE network scenario, what if we wanted to create a network structure as such:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
By default docker creates only 1 default internal BRIDGE network.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# How do we see the network settings and the IP address assigned to a container?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Embedded DNS

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Containers can connect to each other using their names:
#
# mysql.connect ( 172.17.0.3 )  << not ideal bcoz the container may get a different IP address next time re-started
#
# mysql.connect ( mysql-service )  << given a name to a container, can connect all times
#
# In order the second option to work, docker has a built in DNS server that helps containers
# to resolve each other's IP addresses using the container name
#
# Note that built-in DNS server always have an IP address of 127.0.0.11.
#
# So how does docker implement networking?

# %% [markdown]
# ![image.png](attachment:image.png)
