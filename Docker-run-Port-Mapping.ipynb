# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Back to the example, we run a simple webapp in a container;
#
# docker run kodekloud/webapp
#
# The underlying host where the docker is installed is called docker host (with private IP address of 192.168.1.5). When we run a containerized web-app, like above, how to access the application? We know that port 5000 is being listened in the container by the web-app.
#
# But what IP is to use? The container has a private IP assigned to it: 172.17.0.2. In the docker host, you can use the container's private IP:
#
# http://172.17.0.2:5000
#
# If the same container with private IP 172.17.0.2 was created with the command:
# docker run -p 80:5000 kodekloud/webapp
#
# Then the webapp would be accessible in two ways:
#
# http://172.17.0.2:5000   << using the private ip address of the container
# http://192.168.1.5:80    << using the private IP address of the docker host

# %% [raw]
# (base) hakan@hakan-VirtualBox:~$ docker run kodekloud/webapp
# Unable to find image 'kodekloud/webapp:latest' locally
# latest: Pulling from kodekloud/webapp
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)

# %% [raw]
# (base) hakan@hakan-VirtualBox:~$ docker ps
# CONTAINER ID   IMAGE              COMMAND                  CREATED              STATUS              PORTS     NAMES
# b36f038fad54   kodekloud/webapp   "/bin/sh -c 'FLASK_A…"   About a minute ago   Up About a minute             awesome_driscoll
# (base) hakan@hakan-VirtualBox:~$ docker inspect b36f038fad54
# [
#     {
#         "Id": "b36f038fad547c6fe1d2c2642d8dc443ba7091a5aaeeb9aacd89ef9e5b170b18",
#         "Created": "2022-02-08T13:29:55.696052049Z",
#         "Path": "/bin/sh",
#         "Args": [
#             "-c",
#             "FLASK_APP=/opt/app.py flask run --host=0.0.0.0"
#         ],
#         "State": {
#             "Status": "running",
#             "Running": true,
#             "Paused": false,
#             "Restarting": false,
#             "OOMKilled": false,
#             "Dead": false,
#             "Pid": 20033,
#             "ExitCode": 0,
#             "Error": "",
#             "StartedAt": "2022-02-08T13:29:56.337387881Z",
#             "FinishedAt": "0001-01-01T00:00:00Z"
#         },
#         "Image": "sha256:1a45ba829f10d32685d9e1a932c6f95089840d870117768b67d496b276fc33dd",
#         "ResolvConfPath": "/var/lib/docker/containers/b36f038fad547c6fe1d2c2642d8dc443ba7091a5aaeeb9aacd89ef9e5b170b18/resolv.conf",
#         "HostnamePath": "/var/lib/docker/containers/b36f038fad547c6fe1d2c2642d8dc443ba7091a5aaeeb9aacd89ef9e5b170b18/hostname",
#         "HostsPath": "/var/lib/docker/containers/b36f038fad547c6fe1d2c2642d8dc443ba7091a5aaeeb9aacd89ef9e5b170b18/hosts",
#         "LogPath": "/var/lib/docker/containers/b36f038fad547c6fe1d2c2642d8dc443ba7091a5aaeeb9aacd89ef9e5b170b18/b36f038fad547c6fe1d2c2642d8dc443ba7091a5aaeeb9aacd89ef9e5b170b18-json.log",
#         "Name": "/awesome_driscoll",
#         "RestartCount": 0,
#         "Driver": "overlay2",
#         "Platform": "linux",
#         "MountLabel": "",
#         "ProcessLabel": "",
#         "AppArmorProfile": "docker-default",
#         "ExecIDs": null,
#         "HostConfig": {
#             "Binds": null,
#             "ContainerIDFile": "",
#             "LogConfig": {
#                 "Type": "json-file",
#                 "Config": {}
#             },
#             "NetworkMode": "default",
#             "PortBindings": {},           <<< no port bindings because of the lack of -p 80:5000 option
#             "RestartPolicy": {
#                 "Name": "no",
#                 "MaximumRetryCount": 0
#             },
#             "AutoRemove": false,
#             "VolumeDriver": "",
#             "VolumesFrom": null,
#             "CapAdd": null,
#             "CapDrop": null,
#             "CgroupnsMode": "host",
#             "Dns": [],
#             "DnsOptions": [],
#             "DnsSearch": [],
#             "ExtraHosts": null,
#             "GroupAdd": null,
#             "IpcMode": "private",
#             "Cgroup": "",
#             "Links": null,
#             "OomScoreAdj": 0,
#             "PidMode": "",
#             "Privileged": false,
#             "PublishAllPorts": false,
#             "ReadonlyRootfs": false,
#             "SecurityOpt": null,
#             "UTSMode": "",
#             "UsernsMode": "",
#             "ShmSize": 67108864,
#             "Runtime": "runc",
#             "ConsoleSize": [
#                 0,
#                 0
#             ],
#             "Isolation": "",
#             "CpuShares": 0,
#             "Memory": 0,
#             "NanoCpus": 0,
#             "CgroupParent": "",
#             "BlkioWeight": 0,
#             "BlkioWeightDevice": [],
#             "BlkioDeviceReadBps": null,
#             "BlkioDeviceWriteBps": null,
#             "BlkioDeviceReadIOps": null,
#             "BlkioDeviceWriteIOps": null,
#             "CpuPeriod": 0,
#             "CpuQuota": 0,
#             "CpuRealtimePeriod": 0,
#             "CpuRealtimeRuntime": 0,
#             "CpusetCpus": "",
#             "CpusetMems": "",
#             "Devices": [],
#             "DeviceCgroupRules": null,
#             "DeviceRequests": null,
#             "KernelMemory": 0,
#             "KernelMemoryTCP": 0,
#             "MemoryReservation": 0,
#             "MemorySwap": 0,
#             "MemorySwappiness": null,
#             "OomKillDisable": false,
#             "PidsLimit": null,
#             "Ulimits": null,
#             "CpuCount": 0,
#             "CpuPercent": 0,
#             "IOMaximumIOps": 0,
#             "IOMaximumBandwidth": 0,
#             "MaskedPaths": [
#                 "/proc/asound",
#                 "/proc/acpi",
#                 "/proc/kcore",
#                 "/proc/keys",
#                 "/proc/latency_stats",
#                 "/proc/timer_list",
#                 "/proc/timer_stats",
#                 "/proc/sched_debug",
#                 "/proc/scsi",
#                 "/sys/firmware"
#             ],
#             "ReadonlyPaths": [
#                 "/proc/bus",
#                 "/proc/fs",
#                 "/proc/irq",
#                 "/proc/sys",
#                 "/proc/sysrq-trigger"
#             ]
#         },
#         "GraphDriver": {
#             "Data": {
#                 "LowerDir": "/var/lib/docker/overlay2/157608cc764e5612263c8e0adbfab6bd20509f41d00a151970aa61d3b6c14eaa-init/diff:/var/lib/docker/overlay2/5b76c5019bcb6170e9ec52da0b449f8f29faa0acc21b3852e8e7273453c63697/diff:/var/lib/docker/overlay2/8df837336efddd4e0043bdaaefd2aa39affd7196c724248cc7b9396046f0202a/diff:/var/lib/docker/overlay2/d9cb6337ff88016c2fea8fb07f8bfdc33393d0282c92a5a4b8c5d7042c0f241d/diff:/var/lib/docker/overlay2/f0a226b32f464852710623040994235016babdfbbb792a47b7aa9dc055420433/diff:/var/lib/docker/overlay2/56b7c4b29d232a812cf316cd0ccb04a5c188001758b57800aeb5eb92d8c559d5/diff:/var/lib/docker/overlay2/2c0613b9eab1eb3fd07eb588ca8210940c2f039e9b8dea0161b11c6e4b5d41eb/diff:/var/lib/docker/overlay2/df3664928ea560e47c865925e26655ef72a92fec24a26e0a7ae9e1871a883e28/diff:/var/lib/docker/overlay2/8bd22731f14995ab816bd074b1874c0bbcac074ea11e395462d7348634621f70/diff",
#                 "MergedDir": "/var/lib/docker/overlay2/157608cc764e5612263c8e0adbfab6bd20509f41d00a151970aa61d3b6c14eaa/merged",
#                 "UpperDir": "/var/lib/docker/overlay2/157608cc764e5612263c8e0adbfab6bd20509f41d00a151970aa61d3b6c14eaa/diff",
#                 "WorkDir": "/var/lib/docker/overlay2/157608cc764e5612263c8e0adbfab6bd20509f41d00a151970aa61d3b6c14eaa/work"
#             },
#             "Name": "overlay2"
#         },
#         "Mounts": [],
#         "Config": {
#             "Hostname": "b36f038fad54",
#             "Domainname": "",
#             "User": "",
#             "AttachStdin": false,
#             "AttachStdout": true,
#             "AttachStderr": true,
#             "Tty": false,
#             "OpenStdin": false,
#             "StdinOnce": false,
#             "Env": [
#                 "PATH=/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin"
#             ],
#             "Cmd": null,
#             "Image": "kodekloud/webapp",
#             "Volumes": null,
#             "WorkingDir": "",
#             "Entrypoint": [
#                 "/bin/sh",
#                 "-c",
#                 "FLASK_APP=/opt/app.py flask run --host=0.0.0.0"
#             ],
#             "OnBuild": null,
#             "Labels": {}
#         },
#         "NetworkSettings": {
#             "Bridge": "",
#             "SandboxID": "6bd70b6ca9548231e75f1566fe5d27c2e45eb54f43918156dbb19d3fbe761faf",
#             "HairpinMode": false,
#             "LinkLocalIPv6Address": "",
#             "LinkLocalIPv6PrefixLen": 0,
#             "Ports": {},
#             "SandboxKey": "/var/run/docker/netns/6bd70b6ca954",
#             "SecondaryIPAddresses": null,
#             "SecondaryIPv6Addresses": null,
#             "EndpointID": "82b9dc753c5d1b87c8f16cd13ddd0a78aed99f0e1d5aafcdac6e41343426adce",
#             "Gateway": "172.17.0.1",
#             "GlobalIPv6Address": "",
#             "GlobalIPv6PrefixLen": 0,
#             "IPAddress": "172.17.0.2",
#             "IPPrefixLen": 16,
#             "IPv6Gateway": "",
#             "MacAddress": "02:42:ac:11:00:02",
#             "Networks": {
#                 "bridge": {
#                     "IPAMConfig": null,
#                     "Links": null,
#                     "Aliases": null,
#                     "NetworkID": "e067fc5d8c0abb1326ea4e1f6c7f15145b5dfb72754a5bba6d3c7aeb6105dd38",
#                     "EndpointID": "82b9dc753c5d1b87c8f16cd13ddd0a78aed99f0e1d5aafcdac6e41343426adce",
#                     "Gateway": "172.17.0.1",
#                     "IPAddress": "172.17.0.2",    << the containers own IP address
#                     "IPPrefixLen": 16,
#                     "IPv6Gateway": "",
#                     "GlobalIPv6Address": "",
#                     "GlobalIPv6PrefixLen": 0,
#                     "MacAddress": "02:42:ac:11:00:02",
#                     "DriverOpts": null
#                 }
#             }
#         }
#     }
# ]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So, accessing the webserver via the container's IP address and the port 5000 works

# %% [raw]
# Note that we have run the container via
#
# docker run kodekloud/webapp
#
# There is no PAT/NAT translation via -p 80:5000 option. Here is a proof:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# It seems that we have a previously installed APACHE2 server listening the local port 80.
# Lets uninstall it:
#
# (base) hakan@hakan-VirtualBox:~$ sudo /etc/init.d/apache2 stop
# [sudo] password for hakan:
# [ ok ] Stopping apache2 (via systemctl): apache2.service.
# (base) hakan@hakan-VirtualBox:~$ sudo apt remove apache2

# %% [raw]
# PLets know check if port 80 is being listened to:
#
# (base) hakan@hakan-VirtualBox:~$ sudo lsof -i:80 -P -n | grep LISTEN
# (base) hakan@hakan-VirtualBox:~$

# %% [raw]
# Since there is no output, we conclude that nothing is listening port 80 in our ubuntu VM.
#
# We can verify this in the browser:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Lets now kill the container:
#
# (base) hakan@hakan-VirtualBox:~$ docker ps
# CONTAINER ID   IMAGE              COMMAND                  CREATED          STATUS          PORTS     NAMES
# b36f038fad54   kodekloud/webapp   "/bin/sh -c 'FLASK_A…"   31 minutes ago   Up 31 minutes             awesome_driscoll
# (base) hakan@hakan-VirtualBox:~$ docker kill awesome_driscoll
# awesome_driscoll
#
# Lets remove all the stopped containers:
# (base) hakan@hakan-VirtualBox:~$ docker container prune
# WARNING! This will remove all stopped containers.
# Are you sure you want to continue? [y/N] y
# Deleted Containers:
# b36f038fad547c6fe1d2c2642d8dc443ba7091a5aaeeb9aacd89ef9e5b170b18
#
# Total reclaimed space: 570B
# (base) hakan@hakan-VirtualBox:~$ docker ps -a
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES
#
# (base) hakan@hakan-VirtualBox:~$ docker run -p 80:5000 kodekloud/webapp
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# (base) hakan@hakan-VirtualBox:~$ docker ps
# CONTAINER ID   IMAGE              COMMAND                  CREATED          STATUS          PORTS                                   NAMES
# 1d2f6f053215   kodekloud/webapp   "/bin/sh -c 'FLASK_A…"   10 minutes ago   Up 10 minutes   0.0.0.0:80->5000/tcp, :::80->5000/tcp   hardcore_jones
#
# (base) hakan@hakan-VirtualBox:~$ docker inspect 1d2f6f053215
# [
#     {
#         "Id": "1d2f6f053215bdd3b3f731c36421bd6429ccae6b70b378086d036bc27e2d0f72",
#         "Created": "2022-02-08T14:04:06.375942905Z",
#         "Path": "/bin/sh",
#         "Args": [
#             "-c",
#             "FLASK_APP=/opt/app.py flask run --host=0.0.0.0"
#         ],
#         "State": {
#             "Status": "running",
#             "Running": true,
#             "Paused": false,
#             "Restarting": false,
#             "OOMKilled": false,
#             "Dead": false,
#             "Pid": 24480,
#             "ExitCode": 0,
#             "Error": "",
#             "StartedAt": "2022-02-08T14:04:06.846376926Z",
#             "FinishedAt": "0001-01-01T00:00:00Z"
#         },
#         "Image": "sha256:1a45ba829f10d32685d9e1a932c6f95089840d870117768b67d496b276fc33dd",
#         "ResolvConfPath": "/var/lib/docker/containers/1d2f6f053215bdd3b3f731c36421bd6429ccae6b70b378086d036bc27e2d0f72/resolv.conf",
#         "HostnamePath": "/var/lib/docker/containers/1d2f6f053215bdd3b3f731c36421bd6429ccae6b70b378086d036bc27e2d0f72/hostname",
#         "HostsPath": "/var/lib/docker/containers/1d2f6f053215bdd3b3f731c36421bd6429ccae6b70b378086d036bc27e2d0f72/hosts",
#         "LogPath": "/var/lib/docker/containers/1d2f6f053215bdd3b3f731c36421bd6429ccae6b70b378086d036bc27e2d0f72/1d2f6f053215bdd3b3f731c36421bd6429ccae6b70b378086d036bc27e2d0f72-json.log",
#         "Name": "/hardcore_jones",
#         "RestartCount": 0,
#         "Driver": "overlay2",
#         "Platform": "linux",
#         "MountLabel": "",
#         "ProcessLabel": "",
#         "AppArmorProfile": "docker-default",
#         "ExecIDs": null,
#         "HostConfig": {
#             "Binds": null,
#             "ContainerIDFile": "",
#             "LogConfig": {
#                 "Type": "json-file",
#                 "Config": {}
#             },
#             "NetworkMode": "default",
#             "PortBindings": {                        <<<< Port Bindings are done here!
#                 "5000/tcp": [
#                     {
#                         "HostIp": "",
#                         "HostPort": "80"
#                     }
#                 ]
#             },
#             "RestartPolicy": {
#                 "Name": "no",
#                 "MaximumRetryCount": 0
#             },
#             "AutoRemove": false,
#             "VolumeDriver": "",
#             "VolumesFrom": null,
#             "CapAdd": null,
#             "CapDrop": null,
#             "CgroupnsMode": "host",
#             "Dns": [],
#             "DnsOptions": [],
#             "DnsSearch": [],
#             "ExtraHosts": null,
#             "GroupAdd": null,
#             "IpcMode": "private",
#             "Cgroup": "",
#             "Links": null,
#             "OomScoreAdj": 0,
#             "PidMode": "",
#             "Privileged": false,
#             "PublishAllPorts": false,
#             "ReadonlyRootfs": false,
#             "SecurityOpt": null,
#             "UTSMode": "",
#             "UsernsMode": "",
#             "ShmSize": 67108864,
#             "Runtime": "runc",
#             "ConsoleSize": [
#                 0,
#                 0
#             ],
#             "Isolation": "",
#             "CpuShares": 0,
#             "Memory": 0,
#             "NanoCpus": 0,
#             "CgroupParent": "",
#             "BlkioWeight": 0,
#             "BlkioWeightDevice": [],
#             "BlkioDeviceReadBps": null,
#             "BlkioDeviceWriteBps": null,
#             "BlkioDeviceReadIOps": null,
#             "BlkioDeviceWriteIOps": null,
#             "CpuPeriod": 0,
#             "CpuQuota": 0,
#             "CpuRealtimePeriod": 0,
#             "CpuRealtimeRuntime": 0,
#             "CpusetCpus": "",
#             "CpusetMems": "",
#             "Devices": [],
#             "DeviceCgroupRules": null,
#             "DeviceRequests": null,
#             "KernelMemory": 0,
#             "KernelMemoryTCP": 0,
#             "MemoryReservation": 0,
#             "MemorySwap": 0,
#             "MemorySwappiness": null,
#             "OomKillDisable": false,
#             "PidsLimit": null,
#             "Ulimits": null,
#             "CpuCount": 0,
#             "CpuPercent": 0,
#             "IOMaximumIOps": 0,
#             "IOMaximumBandwidth": 0,
#             "MaskedPaths": [
#                 "/proc/asound",
#                 "/proc/acpi",
#                 "/proc/kcore",
#                 "/proc/keys",
#                 "/proc/latency_stats",
#                 "/proc/timer_list",
#                 "/proc/timer_stats",
#                 "/proc/sched_debug",
#                 "/proc/scsi",
#                 "/sys/firmware"
#             ],
#             "ReadonlyPaths": [
#                 "/proc/bus",
#                 "/proc/fs",
#                 "/proc/irq",
#                 "/proc/sys",
#                 "/proc/sysrq-trigger"
#             ]
#         },
#         "GraphDriver": {
#             "Data": {
#                 "LowerDir": "/var/lib/docker/overlay2/9563b679f3846565031bde85d359e92dc20aa60d2dbde974ab20f008f69353f3-init/diff:/var/lib/docker/overlay2/5b76c5019bcb6170e9ec52da0b449f8f29faa0acc21b3852e8e7273453c63697/diff:/var/lib/docker/overlay2/8df837336efddd4e0043bdaaefd2aa39affd7196c724248cc7b9396046f0202a/diff:/var/lib/docker/overlay2/d9cb6337ff88016c2fea8fb07f8bfdc33393d0282c92a5a4b8c5d7042c0f241d/diff:/var/lib/docker/overlay2/f0a226b32f464852710623040994235016babdfbbb792a47b7aa9dc055420433/diff:/var/lib/docker/overlay2/56b7c4b29d232a812cf316cd0ccb04a5c188001758b57800aeb5eb92d8c559d5/diff:/var/lib/docker/overlay2/2c0613b9eab1eb3fd07eb588ca8210940c2f039e9b8dea0161b11c6e4b5d41eb/diff:/var/lib/docker/overlay2/df3664928ea560e47c865925e26655ef72a92fec24a26e0a7ae9e1871a883e28/diff:/var/lib/docker/overlay2/8bd22731f14995ab816bd074b1874c0bbcac074ea11e395462d7348634621f70/diff",
#                 "MergedDir": "/var/lib/docker/overlay2/9563b679f3846565031bde85d359e92dc20aa60d2dbde974ab20f008f69353f3/merged",
#                 "UpperDir": "/var/lib/docker/overlay2/9563b679f3846565031bde85d359e92dc20aa60d2dbde974ab20f008f69353f3/diff",
#                 "WorkDir": "/var/lib/docker/overlay2/9563b679f3846565031bde85d359e92dc20aa60d2dbde974ab20f008f69353f3/work"
#             },
#             "Name": "overlay2"
#         },
#         "Mounts": [],
#         "Config": {
#             "Hostname": "1d2f6f053215",
#             "Domainname": "",
#             "User": "",
#             "AttachStdin": false,
#             "AttachStdout": true,
#             "AttachStderr": true,
#             "ExposedPorts": {
#                 "5000/tcp": {}
#             },
#             "Tty": false,
#             "OpenStdin": false,
#             "StdinOnce": false,
#             "Env": [
#                 "PATH=/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin"
#             ],
#             "Cmd": null,
#             "Image": "kodekloud/webapp",
#             "Volumes": null,
#             "WorkingDir": "",
#             "Entrypoint": [
#                 "/bin/sh",
#                 "-c",
#                 "FLASK_APP=/opt/app.py flask run --host=0.0.0.0"
#             ],
#             "OnBuild": null,
#             "Labels": {}
#         },
#         "NetworkSettings": {
#             "Bridge": "",
#             "SandboxID": "d587a15cc7f8f00331cb7b8ed8c0d31417851383cbcb3961ffe67a60b1bcd943",
#             "HairpinMode": false,
#             "LinkLocalIPv6Address": "",
#             "LinkLocalIPv6PrefixLen": 0,
#             "Ports": {
#                 "5000/tcp": [
#                     {
#                         "HostIp": "0.0.0.0",
#                         "HostPort": "80"
#                     },
#                     {
#                         "HostIp": "::",
#                         "HostPort": "80"
#                     }
#                 ]
#             },
#             "SandboxKey": "/var/run/docker/netns/d587a15cc7f8",
#             "SecondaryIPAddresses": null,
#             "SecondaryIPv6Addresses": null,
#             "EndpointID": "8816b0a924295a69f4745c91c2276f06728cd41a7ce87e1220da5802dd784239",
#             "Gateway": "172.17.0.1",
#             "GlobalIPv6Address": "",
#             "GlobalIPv6PrefixLen": 0,
#             "IPAddress": "172.17.0.2",
#             "IPPrefixLen": 16,
#             "IPv6Gateway": "",
#             "MacAddress": "02:42:ac:11:00:02",
#             "Networks": {
#                 "bridge": {
#                     "IPAMConfig": null,
#                     "Links": null,
#                     "Aliases": null,
#                     "NetworkID": "e067fc5d8c0abb1326ea4e1f6c7f15145b5dfb72754a5bba6d3c7aeb6105dd38",
#                     "EndpointID": "8816b0a924295a69f4745c91c2276f06728cd41a7ce87e1220da5802dd784239",
#                     "Gateway": "172.17.0.1",
#                     "IPAddress": "172.17.0.2",   <<< The container's assigned IP address
#                     "IPPrefixLen": 16,
#                     "IPv6Gateway": "",
#                     "GlobalIPv6Address": "",
#                     "GlobalIPv6PrefixLen": 0,
#                     "MacAddress": "02:42:ac:11:00:02",
#                     "DriverOpts": null
#                 }
#             }
#         }
#     }
# ]

# %% [raw]
# Note that http://172.17.0.2:5000 also accesses the web server:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Observation: Note that the Gateaway IP is 172.17.0.1. If we access port 80 at it:

# %% [markdown]
# ![image.png](attachment:image.png)
