# %% [raw]
# At this point, we have learned about
#
#  - containers
#  - images
#  - docker CLI
#  - docker-compose
#
# We still don't know how to actually use Docker in a production
# environment; how do we actually develop an app that uses Docker
# and then eventually push it to some outside hosting service such
# as AWS or Digital Ocean?
#
# In this section, we will show you a couple of diagrams to give you
# a complete overview of the flow that we are going to implement;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Flow Specifics

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Any changes in the master branch will eventually be released to a hosting platform such as AWS.
#
# Feature branch contains changes for a new feature development. Imagine that multiple developers are working on the feature branch.
#
# You will pull the feature branch, make your own changes, test them and push the changes into the feature branch. After feature branch is ready with your latest changes, you will create a pull request to master branch. Once pull request is initiated, a set of test cases will run on Travis CI to validate the code in merged master branch;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# After Travis CI validates the merged master via passing tests, it will
# deploy the app to AWS Hosting

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# (base) hakan@hakan-VirtualBox:~$ node -v
# v12.13.1

# %% [raw]
# (base) hakan@hakan-VirtualBox:~/Docker$ nvm ls
# ->     v12.13.1
#         v16.6.1
#          system
# default -> v12.13.1
# iojs -> N/A (default)
# unstable -> N/A (default)
# node -> stable (-> v16.6.1) (default)
# stable -> 16.6 (-> v16.6.1) (default)
# lts/* -> lts/fermium (-> N/A)
# lts/argon -> v4.9.1 (-> N/A)
# lts/boron -> v6.17.1 (-> N/A)
# lts/carbon -> v8.17.0 (-> N/A)
# lts/dubnium -> v10.24.1 (-> N/A)
# lts/erbium -> v12.22.4 (-> N/A)
# lts/fermium -> v14.17.4 (-> N/A)
# (base) hakan@hakan-VirtualBox:~/Docker$ nvm use 16.6.1
# Now using node v16.6.1 (npm v7.20.3)
# (base) hakan@hakan-VirtualBox:~/Docker$ node -v
# v16.6.1
# (base) hakan@hakan-VirtualBox:~/Docker$ npx create-react-app frontend-2
#
# NOTE! Event though we use frontend directory in the lecture notes below, we will use frontend-2 directory
# actually. Keep this in mind

# %% [raw]
# (base) hakan@hakan-VirtualBox:~/Docker$ cd frontend/
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ ls -la
# total 1164
# drwxrwxr-x   6 hakan hakan    4096 helmi 24 11:02 .
# drwxr-xr-x  11 hakan hakan    4096 helmi 24 11:00 ..
# drwxrwxr-x   8 hakan hakan    4096 helmi 24 11:03 .git
# -rw-rw-r--   1 hakan hakan     310 helmi 24 11:02 .gitignore
# drwxrwxr-x 805 hakan hakan   32768 helmi 24 11:03 node_modules
# -rw-rw-r--   1 hakan hakan     811 helmi 24 11:03 package.json
# -rw-rw-r--   1 hakan hakan 1120927 helmi 24 11:03 package-lock.json
# drwxrwxr-x   2 hakan hakan    4096 helmi 24 11:02 public
# -rw-rw-r--   1 hakan hakan    3359 helmi 24 11:02 README.md
# drwxrwxr-x   2 hakan hakan    4096 helmi 24 11:02 src

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ npm run test
#
#  PASS  src/App.test.js
#   ✓ renders learn react link (85 ms)
#
# Test Suites: 1 passed, 1 total
# Tests:       1 passed, 1 total
# Snapshots:   0 total
# Time:        4.476 s
# Ran all test suites.
#
# Watch Usage: Press w to show more.

# %% [raw]
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ ls -l
# total 1148
# drwxrwxr-x 805 hakan hakan   32768 helmi 24 11:03 node_modules
# -rw-rw-r--   1 hakan hakan     811 helmi 24 11:03 package.json
# -rw-rw-r--   1 hakan hakan 1120927 helmi 24 11:03 package-lock.json
# drwxrwxr-x   2 hakan hakan    4096 helmi 24 11:02 public
# -rw-rw-r--   1 hakan hakan    3359 helmi 24 11:02 README.md
# drwxrwxr-x   2 hakan hakan    4096 helmi 24 11:02 src
#
# note that there is no "build" directory under frontend
#
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ npm run build
#
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ ls -l
# total 1152
# drwxrwxr-x   3 hakan hakan    4096 helmi 24 11:13 build         << added after "npm run build"
# drwxrwxr-x 806 hakan hakan   32768 helmi 24 11:13 node_modules
# -rw-rw-r--   1 hakan hakan     811 helmi 24 11:03 package.json
# -rw-rw-r--   1 hakan hakan 1120927 helmi 24 11:03 package-lock.json
# drwxrwxr-x   2 hakan hakan    4096 helmi 24 11:02 public
# -rw-rw-r--   1 hakan hakan    3359 helmi 24 11:02 README.md
# drwxrwxr-x   2 hakan hakan    4096 helmi 24 11:02 src

# %% [raw]
# (base) hakan@hakan-VirtualBox:~/Docker/frontend/build/static/js$ ls -la
# total 500
# drwxrwxr-x 2 hakan hakan   4096 helmi 24 11:13 .
# drwxrwxr-x 5 hakan hakan   4096 helmi 24 11:13 ..
# -rw-rw-r-- 1 hakan hakan   4597 helmi 24 11:13 787.cda612ba.chunk.js
# -rw-rw-r-- 1 hakan hakan  10281 helmi 24 11:13 787.cda612ba.chunk.js.map
# -rw-rw-r-- 1 hakan hakan 134004 helmi 24 11:13 main.8acb477b.js      << production grade application to publish
# -rw-rw-r-- 1 hakan hakan   1043 helmi 24 11:13 main.8acb477b.js.LICENSE.txt
# -rw-rw-r-- 1 hakan hakan 340604 helmi 24 11:13 main.8acb477b.js.map

# %% [raw]
# (base) hakan@hakan-VirtualBox:~/Docker/frontend/build$ ls -l
# total 44
# -rw-rw-r-- 1 hakan hakan  605 helmi 24 11:13 asset-manifest.json
# -rw-rw-r-- 1 hakan hakan 3870 helmi 24 11:13 favicon.ico
# -rw-rw-r-- 1 hakan hakan  644 helmi 24 11:13 index.html              << production grade application to publish
# -rw-rw-r-- 1 hakan hakan 5347 helmi 24 11:13 logo192.png
# -rw-rw-r-- 1 hakan hakan 9664 helmi 24 11:13 logo512.png
# -rw-rw-r-- 1 hakan hakan  492 helmi 24 11:13 manifest.json
# -rw-rw-r-- 1 hakan hakan   67 helmi 24 11:13 robots.txt
# drwxrwxr-x 5 hakan hakan 4096 helmi 24 11:13 static

# %% [raw]
# (base) hakan@hakan-VirtualBox:~/Docker/frontend/npm run start

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# The next step is to wrap up our app inside of a container for development purposes:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# NOTE: We need to have 2 docker files, one for development & testing purposes, the other for the production

# %% [raw]
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ ls -la
# total 1172
# drwxrwxr-x   7 hakan hakan    4096 helmi 24 14:09 .
# drwxr-xr-x  11 hakan hakan    4096 helmi 24 11:00 ..
# drwxrwxr-x   3 hakan hakan    4096 helmi 24 11:13 build
# -rw-rw-r--   1 hakan hakan       0 helmi 24 14:09 Dockerfile       << for production
# -rw-rw-r--   1 hakan hakan     113 helmi 24 14:13 Dockerfile.dev   << for development
# drwxrwxr-x   8 hakan hakan    4096 helmi 24 11:03 .git
# -rw-rw-r--   1 hakan hakan     310 helmi 24 11:02 .gitignore
# drwxrwxr-x 806 hakan hakan   32768 helmi 24 11:13 node_modules     << should NOT be copied to the image
# -rw-rw-r--   1 hakan hakan     811 helmi 24 11:03 package.json
# -rw-rw-r--   1 hakan hakan 1120927 helmi 24 11:03 package-lock.json
# drwxrwxr-x   2 hakan hakan    4096 helmi 24 11:02 public
# -rw-rw-r--   1 hakan hakan    3359 helmi 24 11:02 README.md
# drwxrwxr-x   2 hakan hakan    4096 helmi 24 11:02 src

# %% [raw]
# FROM node:16-alpine
#
# WORKDIR '/app/'
#
# COPY package.json .
# RUN npm install               << installs the node_modules dependencies into the image (1)
#
# COPY . .      << Once again, a second copy of node_modules dependencies are copied into the image (2). Not  needed
# CMD [ "npm", "run", "start" ]

# %% [raw]
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ docker build -f Dockerfile.dev .
# Sending build context to Docker daemon  286.1MB   << all the dependencies in (2), not needed
# Step 1/6 : FROM node:16-alpine
# 16-alpine: Pulling from library/node
# 59bf1c3509f3: Already exists
# 683dd8c3cc08: Pull complete
# ae5b2724f19b: Pull complete
# 39190df3f477: Pull complete
# Digest: sha256:2c6c59cf4d34d4f937ddfcf33bab9d8bbad8658d1b9de7b97622566a52167f2b
# Status: Downloaded newer image for node:16-alpine
#  ---> 0e1547c0f4a4
# Step 2/6 : WORKDIR '/app/'
#  ---> Running in deeb8b2c3e9c
# Removing intermediate container deeb8b2c3e9c
#  ---> d8ed87f36e5f
# Step 3/6 : COPY package.json .
#  ---> f0d25af40637
# Step 4/6 : RUN npm install
#  ---> Running in df5c9ef6b73b
# npm WARN deprecated source-map-resolve@0.6.0: See https://github.com/lydell/source-map-resolve#deprecated
# npm WARN deprecated svgo@1.3.2: This SVGO version is no longer supported. Upgrade to v2.x.x.
#
# added 1238 packages, and audited 1239 packages in 1m
#
# 169 packages are looking for funding
#   run `npm fund` for details
#
# 6 moderate severity vulnerabilities
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.
# npm notice
# npm notice New minor version of npm available! 8.3.1 -> 8.5.1
# npm notice Changelog: <https://github.com/npm/cli/releases/tag/v8.5.1>
# npm notice Run `npm install -g npm@8.5.1` to update!
# npm notice
# Removing intermediate container df5c9ef6b73b
#  ---> 0d3948f3a26f
# Step 5/6 : COPY . .
#  ---> a2b74e2dc259
# Step 6/6 : CMD [ "npm", "run", "start" ]
#  ---> Running in c116ae1e88ac
# Removing intermediate container c116ae1e88ac
#  ---> ece51f241917
# Successfully built ece51f241917
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ docker images
# REPOSITORY                TAG         IMAGE ID       CREATED         SIZE
# <none>                    <none>      ece51f241917   7 seconds ago   685MB   << a huge image, lets slim it down
# visits-starter_node-app   latest      3fb63b0a9cef   26 hours ago    176MB
# <none>                    <none>      981e3c3f8c7d   27 hours ago    176MB
# crazymilo/visit-starter   latest      c797fb224b71   2 days ago      176MB
# crazymilo/simpleweb       latest      9350faf50267   2 days ago      175MB
# node                      alpine      c6a2764d974b   13 days ago     170MB
# node                      16-alpine   0e1547c0f4a4   2 weeks ago     110MB
# redis                     latest      f1b6973564e9   4 weeks ago     113MB
# alpine                    latest      c059bfaa849c   3 months ago    5.59MB
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ docker rmi ece51f241917
# Deleted: sha256:ece51f241917417feec409e11e2d50cc4450bf9278e112dd2df2df73f8eeadc0
# Deleted: sha256:a2b74e2dc2591e7497609f7bbc6c4c99aff74a966db1ec086adeea893130e73b
# Deleted: sha256:db533e2eb684cbf9d0227aba29a566211c9bc57823291a42e23fa3491c7fc654
# Deleted: sha256:0d3948f3a26ff532d1f1688c8af13444595bd225a5cd50415411ae74fa7c3c07
# Deleted: sha256:e7e94fbb2f6c1c5eecffff6ac8fc8c3e4505b7b4e77ce487b1aa1cc8d1add3b2
# Deleted: sha256:f0d25af406376c26059a25e867adb2af408afbdae1a4f3c0f875026893c50a1e
# Deleted: sha256:f8a0fba6c41197d7633e0da04414087e977b6ebb68c3a1ce0d7f30f712c5ffe4
# Deleted: sha256:d8ed87f36e5f124f00a9607ac72b8469214eb336eb29070199164ba336d14c02
# Deleted: sha256:c8353752ea0aeadf1e4215e1a66b32d132e3268395a33eafa70be377dd32b431
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$

# %% [raw]
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ rm -rf node_modules/

# %% [raw]
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ docker build -f Dockerfile.dev -t crazymilo/frontend:latest .
# Sending build context to Docker daemon    982kB
# Step 1/6 : FROM node:16-alpine
#  ---> 0e1547c0f4a4
# Step 2/6 : WORKDIR '/app/'
#  ---> Running in 3c17c848713d
# Removing intermediate container 3c17c848713d
#  ---> fe2e2258d837
# Step 3/6 : COPY package.json .
#  ---> 911308451401
# Step 4/6 : RUN npm install
#  ---> Running in e65ee34f76df
# npm WARN deprecated source-map-resolve@0.6.0: See https://github.com/lydell/source-map-resolve#deprecated
# npm WARN deprecated svgo@1.3.2: This SVGO version is no longer supported. Upgrade to v2.x.x.
#
# added 1238 packages, and audited 1239 packages in 1m
#
# 169 packages are looking for funding
#   run `npm fund` for details
#
# 6 moderate severity vulnerabilities
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.
# npm notice
# npm notice New minor version of npm available! 8.3.1 -> 8.5.1
# npm notice Changelog: <https://github.com/npm/cli/releases/tag/v8.5.1>
# npm notice Run `npm install -g npm@8.5.1` to update!
# npm notice
# Removing intermediate container e65ee34f76df
#  ---> 765536d29dcf
# Step 5/6 : COPY . .
#  ---> 10c2b36456dd
# Step 6/6 : CMD [ "npm", "run", "start" ]
#  ---> Running in bad942dcd8fe
# Removing intermediate container bad942dcd8fe
#  ---> bc4049400f06
# Successfully built bc4049400f06
# Successfully tagged crazymilo/frontend:latest
#
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ docker images
# REPOSITORY                TAG         IMAGE ID       CREATED          SIZE
# crazymilo/frontend        latest      bc4049400f06   12 minutes ago   434MB   << smaller, yet still big
# visits-starter_node-app   latest      3fb63b0a9cef   27 hours ago     176MB
# <none>                    <none>      981e3c3f8c7d   27 hours ago     176MB
# crazymilo/visit-starter   latest      c797fb224b71   2 days ago       176MB
# crazymilo/simpleweb       latest      9350faf50267   2 days ago       175MB
# node                      alpine      c6a2764d974b   13 days ago      170MB
# node                      16-alpine   0e1547c0f4a4   2 weeks ago      110MB
# redis                     latest      f1b6973564e9   4 weeks ago      113MB
# alpine                    latest      c059bfaa849c   3 months ago     5.59MB

# %% [raw]
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ docker run crazymilo/frontend:latest
#
# > frontend@0.1.0 start
# > react-scripts start
#
# Compiled successfully!
#
# You can now view frontend in the browser.
#
#   Local:            http://localhost:3000    <<< docker run -p 3000:3000 ce229a9467cc
#   On Your Network:  http://172.17.0.2:3000   <<< this runs fine

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# IF you edit the source code of the react app, and reload the browser, you wont see the changes in the container.
# Why? This is because the container uses its image FS to run. The image FS is a snapshot of the build context .
# when the image is built. If you want to see your changes in the container,
#
#  - re-build the image & re-start the container
#  - some other clever dynamical loading solution --> to be explained next!

# %% [markdown]
# ## DOCKER VOLUMES

# %% [raw]
# In this section, we will show how our changes in the source code will be dynamically reflected to the container.
# We wont need to rebuild the image and re-start the container.
#
# At the moment, our Dockerfile.dev looks like:

# %% [raw]
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ ls -la
# total 40
# drwxrwxr-x  6 hakan hakan 4096 helmi 24 14:24 .
# drwxr-xr-x 11 hakan hakan 4096 helmi 24 11:00 ..
# drwxrwxr-x  3 hakan hakan 4096 helmi 24 11:13 build
# -rw-rw-r--  1 hakan hakan    0 helmi 24 14:09 Dockerfile
# -rw-rw-r--  1 hakan hakan  113 helmi 24 14:13 Dockerfile.dev
# drwxrwxr-x  8 hakan hakan 4096 helmi 24 11:03 .git
# -rw-rw-r--  1 hakan hakan  310 helmi 24 11:02 .gitignore
# -rw-rw-r--  1 hakan hakan  811 helmi 24 11:03 package.json
# drwxrwxr-x  2 hakan hakan 4096 helmi 24 11:02 public       << note this folder is needed for the app to run
# -rw-rw-r--  1 hakan hakan 3359 helmi 24 11:02 README.md
# drwxrwxr-x  2 hakan hakan 4096 helmi 24 11:02 src          << note this folder is needed for the app to run
#
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ cat Dockerfile.dev
# FROM node:16-alpine
#
# WORKDIR '/app/'
#
# COPY package.json .
# RUN npm install
#
# COPY . .      << copying the source code happens here!
# CMD [ "npm", "run", "start" ]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# When 'COPY . .' runs in the docker container, a snapshot of /src and /public folders are copied into Container's FS;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# We need to abandon the 'COPY . .' approach to be able to get the latest changes in /src and /public folders.
# We are going to adjust docker run command to utilize the /src and /public folders in the local folder by using a concept called volumes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# the volume essentially setup a reference to a local folder (e.g. /src) and give us access to the files & folders
# inside of /src folder.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Second switch;  -v $(pwd):/app  where pwd stands for the command "Present Working Directory"
# and -v will map everyhing inside pwd to app folder in the container.
#
# Lets run the above command without the first -v command:
#
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ docker images
# REPOSITORY                TAG         IMAGE ID       CREATED        SIZE
# crazymilo/frontend        latest      ce229a9467cc   3 days ago     429MB
#
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ docker run -p 3000:3000 -v $(pwd):/app crazymilo/frontend
#
# > frontend@0.1.0 start
# > react-scripts start
#
# sh: react-scripts: not found   <<< This happens because we skipped -v /app/node_modules in docker run command

# %% [raw]
# So, what is happening?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# -v $(pwd):/app mapped everything in pwd to the app folder inside the container. The issue with that is that
# Note that;
#
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ ls -la
# total 40
# drwxrwxr-x  6 hakan hakan 4096 helmi 24 14:24 .
# drwxr-xr-x 11 hakan hakan 4096 helmi 24 11:00 ..
# drwxrwxr-x  3 hakan hakan 4096 helmi 24 11:13 build
# -rw-rw-r--  1 hakan hakan    0 helmi 24 14:09 Dockerfile
# -rw-rw-r--  1 hakan hakan  113 helmi 24 14:13 Dockerfile.dev
# drwxrwxr-x  8 hakan hakan 4096 helmi 24 11:03 .git
# -rw-rw-r--  1 hakan hakan  310 helmi 24 11:02 .gitignore
# -rw-rw-r--  1 hakan hakan  811 helmi 24 11:03 package.json
# drwxrwxr-x  2 hakan hakan 4096 helmi 24 11:02 public
# -rw-rw-r--  1 hakan hakan 3359 helmi 24 11:02 README.md
# drwxrwxr-x  2 hakan hakan 4096 helmi 24 11:02 src
#
# We do NOT have node-modules folder, which contains the dependencies, in the local folder.
#
# (!!!) We do have app/node-modules folder in the container FS, but now it is not used, because
# any reference (e.g. /node-modules ) folder in the container will refer to the node-modules folder, which does not exist in the local folder;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# When we use -v /app/node_modules; we declare that there is a node_modules folder under /app and it must NOT be mapped to anything.
#
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ docker run -p 3000:3000 -v /app/node_modules -v $(pwd):/app crazymilo/frontend
#
# ...
# ERROR in EACCES: permission denied, mkdir '/app/node_modules/.cache'   << ERROR

# %% [raw]
# Modified the Dockerfile.dev based on
# https://www.udemy.com/course/docker-and-kubernetes-the-complete-guide/learn/lecture/11437068#questions/14297316

# %% [raw]
# q(base) hakan@hakan-VirtualBox:~/Docker/frontend$ cat Dockerfile.dev
# FROM node:16-alpine
#
# USER node
# RUN mkdir -p /home/node/app
# WORKDIR /home/node/app        << note the WORKDIR has changed!
#
# COPY --chown=node:node ./package.json ./
# RUN npm install
#
# COPY --chown=node:node ./ ./
# CMD [ "npm", "run", "start" ]

# %% [raw]
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ docker build -f Dockerfile.dev -t crazymilo/frontend .
#
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ docker images
# REPOSITORY                TAG         IMAGE ID       CREATED              SIZE
# crazymilo/frontend        latest      e8df71ef1ee3   About a minute ago   430MB  << created
#
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ docker run -p 3000:3000 -v /home/node/app/node_modules -v $(pwd):/home/node/app crazymilo/frontend

# %% [raw]
# Now that volumes work correctly along with localhost:3000, let us edit the source code dynamically:

# %% [raw]
# import logo from './logo.svg';
# import './App.css';
#
# function App() {
#   return (
#     <div className="App">
#       <header className="App-header">
#         <img src={logo} className="App-logo" alt="logo" />
#         <p>
#           Hi there! This line is modified      <<<< The modification
#         </p>
#         <a
#           className="App-link"
#           href="https://reactjs.org"
#           target="_blank"
#           rel="noopener noreferrer"
#         >
#           Learn React
#         </a>
#       </header>
#     </div>
#   );
# }
#
# export default App;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Now the only downside to this approach is that docker run command is too long to execute;
#
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ docker run -p 3000:3000 -v /home/node/app/node_modules -v $(pwd):/home/node/app crazymilo/frontend:latest
#
# We can create a docker-compose.yml file for this;
#
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ ls -la
# total 52
# drwxrwxr-x  8 hakan hakan 4096 helmi 28 14:38 .
# drwxr-xr-x 11 hakan hakan 4096 helmi 24 11:00 ..
# drwxrwxr-x  3 hakan hakan 4096 helmi 24 11:13 build
# -rw-rw-r--  1 hakan hakan  208 helmi 28 14:46 docker-compose.yml
# -rw-rw-r--  1 hakan hakan    0 helmi 24 14:09 Dockerfile
# -rw-rw-r--  1 hakan hakan  199 helmi 28 14:06 Dockerfile.dev
# drwxrwxr-x  8 hakan hakan 4096 helmi 24 11:03 .git
# -rw-rw-r--  1 hakan hakan  310 helmi 24 11:02 .gitignore
# drwxr-xr-x  2 root  root  4096 helmi 28 13:54 node_modules
# drwxr-xr-x  2 root  root  4096 helmi 28 13:54 node-modules
# -rw-rw-r--  1 hakan hakan  811 helmi 24 11:03 package.json
# drwxrwxr-x  2 hakan hakan 4096 helmi 24 11:02 public
# -rw-rw-r--  1 hakan hakan 3359 helmi 24 11:02 README.md
# drwxrwxr-x  2 hakan hakan 4096 helmi 24 11:02 src
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ cat docker-compose.yml
# version: '3.0'
# services:
#   web-frontend:
#     build:
#       context: .
#       dockerfile: Dockerfile.dev
#     ports:
#       - "3000:3000"
#     volumes:
#       - /home/node/app/node_modules/
#       - .:/home/node/app
#
# With this;
#
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ docker-compose up
# Creating frontend_web-frontend_1 ... done
# Attaching to frontend_web-frontend_1
# web-frontend_1  |
# web-frontend_1  | > frontend@0.1.0 start
# web-frontend_1  | > react-scripts start
# web-frontend_1  |
# web-frontend_1  | (node:27) [DEP_WEBPACK_DEV_SERVER_ON_AFTER_SETUP_MIDDLEWARE] DeprecationWarning: 'onAfterSetupMiddleware' option is deprecated. Please use the 'setupMiddlewares' option.
# web-frontend_1  | (Use `node --trace-deprecation ...` to show where the warning was created)
# web-frontend_1  | (node:27) [DEP_WEBPACK_DEV_SERVER_ON_BEFORE_SETUP_MIDDLEWARE] DeprecationWarning: 'onBeforeSetupMiddleware' option is deprecated. Please use the 'setupMiddlewares' option.
# web-frontend_1  | Starting the development server...
# web-frontend_1  |
# web-frontend_1  | Compiled successfully!
# web-frontend_1  |
# web-frontend_1  | You can now view frontend in the browser.
# web-frontend_1  |
# web-frontend_1  |   Local:            http://localhost:3000
# web-frontend_1  |   On Your Network:  http://172.18.0.2:3000
#
# Now
#
# http://localhost:3000
#
# works in the browser.

# %% [raw]
# We dont need in Dockerfile.dev
#
# COPY --chown=node:node ./ ./
#
# So;
#
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ cat Dockerfile.dev
# FROM node:16-alpine
#
# USER node
# RUN mkdir -p /home/node/app
# WORKDIR /home/node/app
#
# COPY --chown=node:node ./package.json ./
# RUN npm install
#
# #COPY --chown=node:node ./ ./     <<< commented out
# CMD [ "npm", "run", "start" ]
#
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ docker-compose up --build
# Building web-frontend
# Step 1/7 : FROM node:16-alpine
#  ---> 0e1547c0f4a4
# Step 2/7 : USER node
#  ---> Using cache
#  ---> 5173e084a431
# Step 3/7 : RUN mkdir -p /home/node/app
#  ---> Using cache
#  ---> ca7cf45918d9
# Step 4/7 : WORKDIR /home/node/app
#  ---> Using cache
#  ---> 8c61789d06c9
# Step 5/7 : COPY --chown=node:node ./package.json ./
#  ---> Using cache
#  ---> b40d7c3f5290
# Step 6/7 : RUN npm install
#  ---> Using cache
#  ---> 2ea8247ccf50
# Step 7/7 : CMD [ "npm", "run", "start" ]
#  ---> Running in ded0b5b3e501
# Removing intermediate container ded0b5b3e501
#  ---> f08f717cf411
# Successfully built f08f717cf411
# Successfully tagged frontend_web-frontend:latest
# Recreating frontend_web-frontend_1 ... done
# Attaching to frontend_web-frontend_1
# web-frontend_1  |
# web-frontend_1  | > frontend@0.1.0 start
# web-frontend_1  | > react-scripts start
# web-frontend_1  |
# web-frontend_1  | (node:27) [DEP_WEBPACK_DEV_SERVER_ON_AFTER_SETUP_MIDDLEWARE] DeprecationWarning: 'onAfterSetupMiddleware' option is deprecated. Please use the 'setupMiddlewares' option.
# web-frontend_1  | (Use `node --trace-deprecation ...` to show where the warning was created)
# web-frontend_1  | (node:27) [DEP_WEBPACK_DEV_SERVER_ON_BEFORE_SETUP_MIDDLEWARE] DeprecationWarning: 'onBeforeSetupMiddleware' option is deprecated. Please use the 'setupMiddlewares' option.
# web-frontend_1  | Starting the development server...
# web-frontend_1  |
# web-frontend_1  | Compiled successfully!
# web-frontend_1  |
# web-frontend_1  | You can now view frontend in the browser.
# web-frontend_1  |
# web-frontend_1  |   Local:            http://localhost:3000
# web-frontend_1  |   On Your Network:  http://172.18.0.2:3000
# web-frontend_1  |
# web-frontend_1  | Note that the development build is not optimized.
# web-frontend_1  | To create a production build, use npm run build.
# web-frontend_1  |
# web-frontend_1  | assets by path static/ 1.49 MiB
# web-frontend_1  |   asset static/js/bundle.js 1.48 MiB [emitted] (name: main) 1 related asset
# web-frontend_1  |   asset static/js/node_modules_web-vitals_dist_web-vitals_js.chunk.js 6.92 KiB [emitted] 1 related asset
# web-frontend_1  |   asset static/media/logo.6ce24c58023cc2f8fd88fe9d219db6c6.svg 2.57 KiB [emitted] (auxiliary name: main)
# web-frontend_1  | asset index.html 1.67 KiB [emitted]
# web-frontend_1  | asset asset-manifest.json 546 bytes [emitted]
# web-frontend_1  | cached modules 1.37 MiB (javascript) 31.3 KiB (runtime) [cached] 122 modules
# web-frontend_1  | webpack 5.69.1 compiled successfully in 956 ms

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# (base) hakan@hakan-VirtualBox:~$ docker ps -a
# CONTAINER ID   IMAGE                   COMMAND                  CREATED         STATUS         PORTS                                       NAMES
# 8107d7a0fb2c   frontend_web-frontend   "docker-entrypoint.s…"   6 minutes ago   Up 6 minutes   0.0.0.0:3000->3000/tcp, :::3000->3000/tcp   frontend_web-frontend_1
#
#
# (base) hakan@hakan-VirtualBox:~/Docker/frontend/src$ cat App.test.js
# import { render, screen } from '@testing-library/react';
# import App from './App';
#
# test('renders learn react link', () => {
#   render(<App />);
#   const linkElement = screen.getByText(/learn react/i);
#   expect(linkElement).toBeInTheDocument();
# });
#
#
# test('renders learn react link 2', () => {     <<< a new test case is added
#   render(<App />);
#   const linkElement = screen.getByText(/learn react/i);
#   expect(linkElement).toBeInTheDocument();
#
#
# (base) hakan@hakan-VirtualBox:~$ docker exec -it frontend_web-frontend_1 sh
# ~/app $ npm run test
#
#  PASS  src/App.test.js
#   ✓ renders learn react link (41 ms)
#   ✓ renders learn react link 2 (7 ms)
#
# Test Suites: 1 passed, 1 total
# Tests:       2 passed, 2 total  << the newly added test case is dynamically loaded via volumes
# Snapshots:   0 total
# Time:        2.156 s
# Ran all test suites.
#
#
# OBSERVATION: To execute the tests, one approach is to:
#
# - docker-compose up --build     << start the container
# - docker exec -it frontend_web-frontend_1 npm run test    << run test cases inside of that container
#
# OBSERVATION: To execute the tests, another option is to create a new service only for running the tests inside
# of docker-compose.yml. Lets see that next;

# %% [raw]
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ cat docker-compose.yml
# version: '3.0'
# services:
#   web-frontend:
#     build:
#       context: .
#       dockerfile: Dockerfile.dev
#     ports:
#       - "3000:3000"
#     volumes:
#       - /home/node/app/node_modules/
#       - .:/home/node/app
#   tests:
#     build:
#       context: .
#       dockerfile: Dockerfile.dev
#     volumes:
#       - /home/node/app/node_modules/
#       - .:/home/node/app
#     command: ["npm", "run", "test"]

# %% [markdown]
# The downside with tests: service inside of docker-compose.yml is that we do not have any STDIN and STDOUT
# connection to the tests container. We can utilize docker attach command to attache to tests container and see if we can then re-run the tests inside of the container, but here is what is happening right now:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Using docker compose, we can NOT connect STDIN of our terminal to STDIN of Test Container. So, lets take a slightly different approach:

# %% [raw]
# (base) hakan@hakan-VirtualBox:~$ docker ps -a
# CONTAINER ID   IMAGE                   COMMAND                  CREATED          STATUS         PORTS                                       NAMES
# 5f78c16fb627   frontend_tests          "docker-entrypoint.s…"   9 minutes ago    Up 9 minutes                                               frontend_tests_1
# 8107d7a0fb2c   frontend_web-frontend   "docker-entrypoint.s…"   43 minutes ago   Up 9 minutes   0.0.0.0:3000->3000/tcp, :::3000->3000/tcp   frontend_web-frontend_1
#
# (base) hakan@hakan-VirtualBox:~$ docker attach frontend_tests_1
# p
# q
# t
# exit
# ^C^C^Cnpm ERR! path /home/node/app
# npm ERR! command failed
# npm ERR! signal SIGINT
# npm ERR! command sh -c react-scripts test
#
# npm ERR! A complete log of this run can be found in:
# npm ERR!     /home/node/.npm/_logs/2022-02-28T14_14_57_531Z-debug-0.log
# (base) hakan@hakan-VirtualBox:~$ docker ps -a
# CONTAINER ID   IMAGE                   COMMAND                  CREATED          STATUS                      PORTS                                       NAMES
# 5f78c16fb627   frontend_tests          "docker-entrypoint.s…"   12 minutes ago   Exited (1) 13 seconds ago                                               frontend_tests_1
# 8107d7a0fb2c   frontend_web-frontend   "docker-entrypoint.s…"   46 minutes ago   Up 12 minutes               0.0.0.0:3000->3000/tcp, :::3000->3000/tcp   frontend_web-frontend_1

# %% [raw]
# OBSERVATION: with tests service running via docker-compose.yml we can NOT interact with the tests.
#
# Lets re-start everything once more time:
#
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ docker-compose down
# Stopping frontend_web-frontend_1 ... done
# Removing frontend_tests_1        ... done
# Removing frontend_web-frontend_1 ... done
# Removing network frontend_default
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ docker ps -a
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES
#
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ docker-compose up
# Creating network "frontend_default" with the default driver
# Creating frontend_tests_1        ... done
# Creating frontend_web-frontend_1 ... done
# Attaching to frontend_web-frontend_1, frontend_tests_1

# %% [raw]
# Lets explain why the docker attach does not work with docker compose:

# %% [raw]
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ docker ps -a
# CONTAINER ID   IMAGE                   COMMAND                  CREATED         STATUS         PORTS                                       NAMES
# cf8dd0a1b45c   frontend_web-frontend   "docker-entrypoint.s…"   2 minutes ago   Up 2 minutes   0.0.0.0:3000->3000/tcp, :::3000->3000/tcp   frontend_web-frontend_1
# 3a89fd99e436   frontend_tests          "docker-entrypoint.s…"   2 minutes ago   Up 2 minutes                                               frontend_tests_1
#
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$
# (base) hakan@hakan-VirtualBox:~/Docker/frontend$ docker exec -it frontend_tests_1 sh
# ~/app $ ps -a
# PID   USER     TIME  COMMAND
#     1 node      0:00 npm run test   << Gives npm process a command "run test", which will span the below processes
#    18 node      0:00 node /home/node/app/node_modules/.bin/react-scripts test
#    25 node      0:04 /usr/local/bin/node /home/node/app/node_modules/react-scripts/scripts/test.js
#    62 node      0:00 sh
#    69 node      0:00 ps -a

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# it is the start.js process that is running the test cases & interacting with the user.
#
# Note that npm process is the primary process with PID 1. When we use docker attach we always
# attach to the primary process of the container, which is the npm process. Since npm process
# does not interact with STDIN, our previous keypresses after docker attach frontend_tests_1
# are ignored by npm.
#
# In summary, creating a tests: service and running it with docker-compose has the problem that
# you cannot interact with the tests. This is the second approach.

# %% [raw]
# Another way to run the tests using the image created:
#
# (base) hakan@hakan-VirtualBox:~/Docker/frontend-2$ docker images
# REPOSITORY                TAG         IMAGE ID       CREATED        SIZE
# crazymilo/frontend-2      latest      ed262777f76f   3 hours ago    292MB  << the image
# frontend-2_tests          latest      3935f1037bf6   7 days ago     368MB
# crazymilo/redis           latest      ec85a4ec98b6   2 weeks ago    36.2MB
# visits-starter_node-app   latest      3fb63b0a9cef   4 weeks ago    176MB
# crazymilo/simpleweb       latest      9350faf50267   4 weeks ago    175MB
# node                      alpine      c6a2764d974b   6 weeks ago    170MB
# node                      16-alpine   0e1547c0f4a4   6 weeks ago    110MB
# redis                     latest      f1b6973564e9   8 weeks ago    113MB
# alpine                    latest      c059bfaa849c   4 months ago   5.59MB
#
# (base) hakan@hakan-VirtualBox:~/Docker/frontend-2$ docker run -it -v /home/node/app/node_modules/ -v $(pwd):/home/node/app -p 3000:3000 ed262777f76f npm run test

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Now, we are going to implement "npm run build"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# When localhost:3000 is triggered on the browser, the dev server inside the container seeing the Local File system serves index.html and main.js files to the browser.
#
# When we utilize npm run build, the production version of index.html and main.js are built in the Local File system, but this time, Dev Server serving those files does not exist anymore;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# We need something like a production server serving index.html and main.js to the browser.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# To solve this we are going to use a HTTP server called nginx, which responds to browser requests with static files. We are going to create a seperate Dockerfile (for production)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# (base) hakan@hakan-VirtualBox:~/Docker/frontend-2$ ls -la
# total 1184
# drwxrwxr-x   7 hakan hakan    4096 maali 20 15:34 .
# drwxr-xr-x  12 hakan hakan    4096 maali 20 10:28 ..
# drwxrwxr-x   3 hakan hakan    4096 maali 20 10:31 build   <<< only the contents this is needed in prod container
# -rw-rw-r--   1 hakan hakan     426 maali 20 14:46 docker-compose.yml
# -rw-rw-r--   1 hakan hakan     247 maali 20 13:40 Dockerfile.dev
# -rw-rw-r--   1 hakan hakan      10 maali 20 14:44 .env
# drwxrwxr-x   8 hakan hakan    4096 maali 20 10:29 .git
# -rw-rw-r--   1 hakan hakan     310 maali 20 10:29 .gitignore
# drwxrwxr-x 804 hakan hakan   36864 maali 20 15:34 node_modules
# -rw-rw-r--   1 hakan hakan     813 maali 20 10:29 package.json
# -rw-rw-r--   1 hakan hakan 1124472 maali 20 15:34 package-lock.json
# drwxrwxr-x   2 hakan hakan    4096 maali 20 10:29 public
# -rw-rw-r--   1 hakan hakan    3359 maali 20 10:29 README.md
# drwxrwxr-x   2 hakan hakan    4096 maali 20 14:37 src
#
# Note that the rest of the files & folders are NOT needed in production container for crazymilo/frontend-2:latest

# %% [raw]
# Also note that we have nginx image in docker hub:
# https://hub.docker.com/_/nginx
#
# so it would be the best if we can use the nginx image to serve our app.

# %% [raw]
# So, on one hand we need node to build the app for production, and on the other hand we need ngix image to serve the built app. So, we somehow need to have 2 base images!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So, our production Dockerfile will have the 2 phases. Only the outcome of "npm run build" (i.e. the build folder)
# will be copied into nginx container, nothing else.

# %% [raw]
# (base) hakan@hakan-VirtualBox:~/Docker/frontend-2$ cat Dockerfile
# FROM node:16-alpine as builder
# USER node
# RUN mkdir -p /home/node/app
# WORKDIR /home/node/app
#
# COPY --chown=node:node ./package.json ./
# RUN npm install
# COPY --chown=node:node ./ ./
# RUN npm run build
#
# # we only care about /home/node/app/build folder
# FROM nginx
# COPY --from=builder /home/node/app/build  /usr/share/nginx/html
# # CMD ["nginx"] --> By default in nginx CMD is this one anyway
#
# !!! Note that each FROM statement ends the previous phase and starts a new phase

# %% [raw]
# (base) hakan@hakan-VirtualBox:~/Docker/frontend-2$ docker build -f Dockerfile -t crazymilo/frontend-2-prod:latest .
# Sending build context to Docker daemon  179.2MB
# Step 1/10 : FROM node:16-alpine as builder
#  ---> 0e1547c0f4a4
# Step 2/10 : USER node
#  ---> Using cache
#  ---> 5c0b04779de3
# Step 3/10 : RUN mkdir -p /home/node/app
#  ---> Using cache
#  ---> f5982c7986c8
# Step 4/10 : WORKDIR /home/node/app
#  ---> Using cache
#  ---> 3e50210a432f
# Step 5/10 : COPY --chown=node:node ./package.json ./
#  ---> 5e6effa743b4
# Step 6/10 : RUN npm install
#  ---> Running in 75f9cca17781
# npm WARN deprecated source-map-resolve@0.6.0: See https://github.com/lydell/source-map-resolve#deprecated
# npm WARN deprecated svgo@1.3.2: This SVGO version is no longer supported. Upgrade to v2.x.x.
#
# added 1227 packages, and audited 1228 packages in 56s
#
# 169 packages are looking for funding
#   run `npm fund` for details
#
# 6 moderate severity vulnerabilities
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.
# npm notice
# npm notice New minor version of npm available! 8.3.1 -> 8.5.5
# npm notice Changelog: <https://github.com/npm/cli/releases/tag/v8.5.5>
# npm notice Run `npm install -g npm@8.5.5` to update!
# npm notice
# Removing intermediate container 75f9cca17781
#  ---> 0a51689b1856
# Step 7/10 : COPY --chown=node:node ./ ./
#  ---> 807898e36e4b
# Step 8/10 : RUN npm run build
#  ---> Running in 6765a6db0cc2
#
# > frontend-2@0.1.0 build
# > react-scripts build
#
# Creating an optimized production build...
# Compiled successfully.
#
# File sizes after gzip:
#
#   43.68 kB (-26 B)  build/static/js/main.23439f29.js
#   1.78 kB           build/static/js/787.907203ed.chunk.js
#   541 B             build/static/css/main.073c9b0a.css
#
# The project was built assuming it is hosted at /.
# You can control this with the homepage field in your package.json.
#
# The build folder is ready to be deployed.
# You may serve it with a static server:
#
#   npm install -g serve
#   serve -s build
#
# Find out more about deployment here:
#
#   https://cra.link/deployment
#
# Removing intermediate container 6765a6db0cc2
#  ---> a8f258d99cbf
# Step 9/10 : FROM nginx
# latest: Pulling from library/nginx
# ae13dd578326: Pull complete
# 6c0ee9353e13: Pull complete
# dca7733b187e: Pull complete
# 352e5a6cac26: Pull complete
# 9eaf108767c7: Pull complete
# be0c016df0be: Pull complete
# Digest: sha256:4ed64c2e0857ad21c38b98345ebb5edb01791a0a10b0e9e3d9ddde185cdbd31a
# Status: Downloaded newer image for nginx:latest
#  ---> f2f70adc5d89
# Step 10/10 : COPY --from=builder /home/node/app/build  /usr/share/nginx/html
#  ---> 4463367c010a
# Successfully built 4463367c010a
# Successfully tagged crazymilo/frontend-2-prod:latest
# (base) hakan@hakan-VirtualBox:~/Docker/frontend-2$ docker images
# REPOSITORY                  TAG         IMAGE ID       CREATED          SIZE
# crazymilo/frontend-2-prod   latest      4463367c010a   10 seconds ago   142MB   << the prod image with nginx
# <none>                      <none>      a8f258d99cbf   20 seconds ago   586MB   << the img from "builder" phase

# %%
(base) hakan@hakan-VirtualBox:~/Docker/frontend-2$ docker run -p 8080:80 crazymilo/frontend-2-prod:latest

Referring to the nginx documentation, it uses port 80 to listen inside of the container.
